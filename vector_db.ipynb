# %% [markdown]
# ### Document Load & Chunking

# %%
# !pip install pymupdf
# !pip install pdfplumber
# from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import PDFPlumberLoader
from typing import List, Dict
import os


# [2] PDF 문서 로드 함수
def load_company_pdfs(pdf_directory: str = "data") -> List[Dict]:
    company_docs = []
    total_companies = 0
    
    print("=== PDF 문서 로드 시작 ===")
    
    for filename in os.listdir(pdf_directory):
        if filename.endswith('.pdf'):
            # 파일명에서 기업 정보 추출
            # 예: 기업분석_보고서_국문_뤼튼테크놀로지스_202504300900.pdf
            company_info = filename.split('_')
            company_name = company_info[3]  # 기업명 추출
            report_date = company_info[4].replace('.pdf', '')  # 날짜 추출
            
            file_path = os.path.join(pdf_directory, filename)
            
            try:
                print(f"\n로딩 중: {company_name}")
                loader = PDFPlumberLoader(file_path)
                docs = loader.load()
                
                # 각 페이지에 기업 정보 메타데이터 추가
                for doc in docs:
                    doc.metadata.update({
                        'company_name': company_name,
                        'report_date': report_date,
                        'source_file': filename
                    })
                
                company_docs.extend(docs)
                total_companies += 1
                print(f"완료: {company_name} ({len(docs)} 페이지)")
                
            except Exception as e:
                print(f"에러 발생 ({filename}): {str(e)}")
    
    print(f"\n=== 로드 완료 ===")
    print(f"총 처리된 기업 수: {total_companies}")
    print(f"총 페이지 수: {len(company_docs)}")
    
    return company_docs
# [3] 실행
pdf_directory = "data"
docs = load_company_pdfs(pdf_directory)

# [4] 로드된 문서 확인
def check_loaded_docs(docs):
    print("\n=== 로드된 문서 확인 ===")
    
    # 기업별 페이지 수 집계
    company_pages = {}
    for doc in docs:
        company_name = doc.metadata['company_name']
        company_pages[company_name] = company_pages.get(company_name, 0) + 1
    
    print("\n기업별 페이지 수:")
    for company, pages in company_pages.items():
        print(f"{company}: {pages}페이지")
    
    # 샘플 메타데이터 확인
    print("\n첫 번째 문서의 메타데이터:")
    print(docs[0].metadata)

# 로드된 문서 확인 실행
check_loaded_docs(docs)

# [1] PDF 로드 및 메타데이터 추가
# file_path = "data/기업분석_보고서_국문_뤼튼테크놀로지스_202504300900.pdf"
# company_info = file_path.split('_')
# company_name = company_info[3]
# report_date = company_info[4].replace('.pdf', '')

# loader = PDFPlumberLoader(file_path)
# docs = loader.load()

# # 각 문서에 기업 메타데이터 추가
# for doc in docs:
#     doc.metadata.update({
#         'company_name': company_name,
#         'report_date': report_date,
#         'source_file': file_path
#     })
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# === PDF 문서 로드 시작 ===
#
# 로딩 중: 네오사피엔스
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 네오사피엔스 (16 페이지)
#
# 로딩 중: 달파
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 달파 (16 페이지)
#
# 로딩 중: 라이너
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 라이너 (16 페이지)
#
# 로딩 중: 렛서
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 렛서 (16 페이지)
#
# 로딩 중: 로아스
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 로아스 (16 페이지)
#
# 로딩 중: 로앤컴퍼니
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 로앤컴퍼니 (16 페이지)
#
# 로딩 중: 뤼이드
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 뤼이드 (16 페이지)
#
# 로딩 중: 뤼튼테크놀로지스
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 뤼튼테크놀로지스 (16 페이지)
#
# 로딩 중: 메이아이
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 메이아이 (16 페이지)
#
# 로딩 중: 모두싸인
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 모두싸인 (16 페이지)
#
# 로딩 중: 스토어링크
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 스토어링크 (16 페이지)
#
# 로딩 중: 스튜디오랩
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 스튜디오랩 (16 페이지)
#
# 로딩 중: 씨드앤
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 씨드앤 (16 페이지)
#
# 로딩 중: 업스테이지
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 업스테이지 (16 페이지)
#
# 로딩 중: 엘리스그룹
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 엘리스그룹 (16 페이지)
#
# 로딩 중: 인핸스
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 인핸스 (16 페이지)
#
# 로딩 중: 자비스앤빌런즈
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 자비스앤빌런즈 (16 페이지)
#
# 로딩 중: 프리윌린
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 프리윌린 (16 페이지)
#
# 로딩 중: 필라이즈
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 완료: 필라이즈 (16 페이지)
#
# 로딩 중: 혜움
# 완료: 혜움 (16 페이지)
#
# === 로드 완료 ===
# 총 처리된 기업 수: 20
# 총 페이지 수: 320
#
# === 로드된 문서 확인 ===
#
# 기업별 페이지 수:
# 네오사피엔스: 16페이지
# 달파: 16페이지
# 라이너: 16페이지
# 렛서: 16페이지
# 로아스: 16페이지
# 로앤컴퍼니: 16페이지
# 뤼이드: 16페이지
# 뤼튼테크놀로지스: 16페이지
# 메이아이: 16페이지
# 모두싸인: 16페이지
# 스토어링크: 16페이지
# 스튜디오랩: 16페이지
# 씨드앤: 16페이지
# 업스테이지: 16페이지
# 엘리스그룹: 16페이지
# 인핸스: 16페이지
# 자비스앤빌런즈: 16페이지
# 프리윌린: 16페이지
# 필라이즈: 16페이지
# 혜움: 16페이지
#
# 첫 번째 문서의 메타데이터:
# {'source': 'data\\기업분석_보고서_국문_네오사피엔스_202504301027.pdf', 'file_path': 'data\\기업분석_보고서_국문_네오사피엔스_202504301027.pdf', 'page': 0, 'total_pages': 16, 'Creator': 'OZ Report Viewer', 'CreationDate': 'D:20250430102758', 'Producer': 'oz', 'Author': 'Forcs Co.,Ltd.', 'Title': 'NCO1100M00OZ01.ozr', 'Subject': '', 'Keywords': '', 'company_name': '네오사피엔스', 'report_date': '202504301027', 'source_file': '기업분석_보고서_국문_네오사피엔스_202504301027.pdf'}

# %%
print(docs[10].page_content)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# 표 헤더 패턴 정의
TABLE_HEADERS = [
    "주요 재무상황 (단위 : 백만원)",
    "재무비율분석",
    "주변지역 동종업체 (응용 소프트웨어 개발 및 공급업)",
    "산업재무 분석 (단위: 백만원, %)",
    "주요 수익성비율",
    "수익성비율 해설",
    "주요 안정성비율",
    "안정성비율 해설",
    "주요 성장성 및 활동성비율",
    "주요 성장성 및 활동성비율 해설",
    "재무상태표(GAAP) (단위: 백만원)",
    "차입금구조(GAAP) (단위: 백만원, %)",
    "손익계산서(GAAP) (단위: 백만원, %)",
    "현금흐름분석(간접법) (단위: 백만원, %)",
    "Watch등급 이력",
    "조기경보내역 (단위: 천원)"
]

# 구분자 생성 (각 헤더를 정규식 패턴으로 변환)
separators = []
for header in TABLE_HEADERS:
    # 괄호와 특수문자를 이스케이프 처리
    escaped_header = header.replace("(", "\(").replace(")", "\)")
    separators.append(escaped_header)

# 기본 구분자 추가
separators.extend(["\n\n", "\n", ".", " ", ""])

# 텍스트 스플리터 생성
text_splitter = RecursiveCharacterTextSplitter(
    separators=separators,
    chunk_size=1500,        # 표 데이터를 고려한 더 큰 청크 크기
    chunk_overlap=200,      # 문맥 유지를 위한 오버랩
    length_function=len,
    is_separator_regex=True # 정규식 패턴 사용
)

# 메타데이터 추가를 위한 함수
def add_table_metadata(text: str) -> dict:
    metadata = {
        "document_type": "financial_report",
        "table_type": "unknown"
    }
    
    for header in TABLE_HEADERS:
        if header in text:
            metadata["table_type"] = header
            break
            
    return metadata

# 문서 분할 및 메타데이터 추가
def split_financial_documents(docs):
    processed_chunks = []
    
    for doc in docs:
        chunks = text_splitter.split_text(doc.page_content)
        
        for chunk in chunks:
            metadata = add_table_metadata(chunk)
            metadata.update(doc.metadata)  # 기존 문서의 메타데이터 유지
            
            processed_chunks.append({
                "content": chunk,
                "metadata": metadata
            })
    
    return processed_chunks

# %%
chunks = split_financial_documents(docs)

print(chunks[-1])
# Out:
# {'content': '경보\n요함.\n최근 상당한 연체 및 연체에 준하는 신용 사건이 발생한 기업으로, 단기간 내 채무불이행 가능성이 매우 높은 수준이므로 이에 대한\n위험\n대비책이 필요함.\n회수의문 연체 및 연체에 준하는 신용사건이 발생한 기업. 채무불이행에 대한 대비책이 필요함.\n휴폐업 피흡수합병, 휴폐업, 청산\n부도 부도 및 부도에 준하는 신용사건이 발생한 기업. 채무불이행에 대한 대비책이 필요함.\n현금흐름등급의 정의\n현금흐름이란 기업의 유동성을 측정하는 가장 직접적인 도구입니다.\n현금흐름등급이란 현금흐름의 건전성에 따라 기업의 지급능력(상환능력을)을 분류한 지표입니다.\n현금흐름등급 현금흐름의등급의 정의 현금흐름등급 현금흐름의등급의 정의\n연간 창출한 현금흐름으로 운전자금 투자수요금액을 충당\nCF1(우수) 현금흐름창출능력이 최상급인 유동성 우수기업 CF4(열위)\n하지 못하는 보통이하의 상태\n영업활동의 수익성 양호하고, 투자수요를 충분히 감당할\nCF2(양호) CF5(위험) 당기의 현금흐름 수익성이 적자인 위험한 상태\n수 있는 상태\n영업활동 현금흐름은 양호하나 신규투자를 위해서는 외부 현금흐름이 2년 연속 적자로서 수익성이 매우 열악한 상\nCF3(보통) CF6(부실)\n자금을 조달해야 하는 상태 태\n16', 'metadata': {'document_type': 'financial_report', 'table_type': 'unknown', 'source': 'data\\기업분석_보고서_국문_혜움_202504301012.pdf', 'file_path': 'data\\기업분석_보고서_국문_혜움_202504301012.pdf', 'page': 15, 'total_pages': 16, 'Creator': 'OZ Report Viewer', 'CreationDate': 'D:20250430101306', 'Producer': 'oz', 'Author': 'Forcs Co.,Ltd.', 'Title': 'NCO1100M00OZ01.ozr', 'Subject': '', 'Keywords': '', 'company_name': '혜움', 'report_date': '202504301012', 'source_file': '기업분석_보고서_국문_혜움_202504301012.pdf'}}

# %%
# 각 표 유형별 청크 수 확인
table_types = {}
for chunk in chunks:
    table_type = chunk["metadata"]["table_type"]
    table_types[table_type] = table_types.get(table_type, 0) + 1

print("\n각 표 유형별 청크 수:")
for table_type, count in table_types.items():
    print(f"{table_type}: {count}개")

# 6. 특정 표 데이터 확인 (예: 재무상태표)
print("\n주요 재무상황 데이터 샘플:")
financial_statements = [
    chunk for chunk in chunks 
    if chunk["metadata"]["table_type"] == "주요 재무상황 (단위 : 백만원)"
]
if financial_statements:
    print(financial_statements[0]["content"][:500])  # 첫 500자만 출력

# 7. 벡터 저장소용 문서 형식으로 변환
from langchain.schema import Document

vectorstore_docs = [
    Document(
        page_content=chunk["content"],
        metadata=chunk["metadata"]
    ) for chunk in chunks
]
# Out:
# 각 표 유형별 청크 수:
# unknown: 216개
# 주요 재무상황 (단위 : 백만원): 20개
# 주변지역 동종업체 (응용 소프트웨어 개발 및 공급업): 13개
# 주요 수익성비율: 20개
# 주요 안정성비율: 20개
# 주요 성장성 및 활동성비율: 20개
# 차입금구조(GAAP) (단위: 백만원, %): 18개
# Watch등급 이력: 20개
# 산업재무 분석 (단위: 백만원, %): 7개
#
# 주요 재무상황 데이터 샘플:
# 02. 주요재무현황
# www.nicebizline.com
# 네오사피엔스(주)│ 883-86-00767
# 주요 재무상황 (단위 : 백만원)
# 결산년일 자산총계 부채총계 자본총계 매출액 영업이익 순이익
# 2024.12.31 11,774 9,740 2,033 6,399 -7,795 -7,665
# 2023.12.31 11,920 2,462 9,457 3,973 -7,202 -6,829
# 2022.12.31 17,322 1,036 16,286 2,340 -5,436 -5,772
# 감사의견 적정 결산일 2024.12.31 회계감사법인 삼도회계법인
# 재무비율분석
# 2024.12.31 2023.12.31 2022.12.31
# 항목
# 대상기업 한은평균 대상기업 한은평균 대상기업 한은평균
# 매출액증가율 % 61.05 - 69.81 3.70 154.01 12.67
# 성장성 총자산증가율 % -1.22 - -31.19 5.91 611.56 9.70
# 영업이익증가율 % - - - - - -
# 총자본순이익율 % -64.70 - -46.7

# %%
print(vectorstore_docs[2].page_content)
# Out:
# 01. 기업개요
# www.nicebizline.com
# 네오사피엔스(주)│ 883-86-00767
# 신용분석 대상업체
# 기업명 네오사피엔스(주) 기업평가등급
# 대표자명 김태수
# 설립일자 2017년 11월 15일 창업일자 -
# 사업자번호 883-86-00767 법인번호 110111-6562866
# 기업형태 중소기업 / 일반
# (J58222) CCC+ [등급구분] 모형등급
# 표준산업분류 평가일 : 2025.04.18 [등급설명] 상거래를 위한 신용능력이 보통 이하이며, 거래
# 응용 소프트웨어 개발 및 공급업 재무일 : 2024.12.31 안정성 저하가 예상되어 주의를 요하는 기업
# 종업원수 73 명 Watch 등급
# 전화번호 02-2155-4548
# (06173)
# 주소
# 서울 강남구 영동대로96길 20, 5층 (삼성동,대화빌딩)
# 유보
# 최근 기업 내/외부 환경의 변화가 발생하였으나, 기업의 신용도
# 홈페이지 - 변화에 유의미한 영향을 미치는 수준은 아님.
# 기준일 : 2025.04.18
# ※ '모형등급'은 수집된 기업정보를 바탕으로 계량모형에 의해 자동 산출된 등급으로, 수집된 정보에 따라 변경될 수 있습니다.
# ※ '평가등급’은 의뢰기업에 대해 계량모형을 통해 산출된 등급과 평가자의 정성적 판단을 기초로 조정된 등급입니다.
# 산업 내 위치 현금흐름등급
# CF5
# 결산일 : 2024.12.31
# 활동성 수익성 안정성 성장성 규모
# * 기업의 현금흐름의 건정성에 따라 지급(상환)능력을 분류합니다.
# 기업평가등급 이력 현금흐름등급 이력
# * 기업평가등급 이력은 연도별 마지막 평가등급과 해당 연도를 표기합니다.
# 기업신용정보 요약현황
# (단위 : 천 원)
# 구분 미해제 단기연체 신용도판단 공공정보 신용도판단(신정) 당좌거래정지/부도 법정관리/화의
# 건수 0 0 0 0
# - -
# 총금액 0 0 0 0
# ※ 신용도판단(한국신용정보원) 항목에는 금융기관에서 발생한 연체, 신용도판단(신정) 항목에는 기업 간 상거래에서 발생한 채무불이행의 건수 및 금액이 표시됩니다.
# 3

# %%
# 8. 청크 품질 확인
print("\n청크 품질 확인:")
for i, chunk in enumerate(chunks[3:6]):  # 처음 3개 청크만 확인
    print(f"\n=== 청크 {i+1} ===")
    print(f"유형: {chunk['metadata']['table_type']}")
    print(f"길이: {len(chunk['content'])} 문자")
    print("내용 미리보기:")
    print(chunk['content'][:200])
    print("-" * 50)
# Out:
# 청크 품질 확인:
#
# === 청크 1 ===
# 유형: 주요 재무상황 (단위 : 백만원)
# 길이: 919 문자
# 내용 미리보기:
# 02. 주요재무현황
# www.nicebizline.com
# 네오사피엔스(주)│ 883-86-00767
# 주요 재무상황 (단위 : 백만원)
# 결산년일 자산총계 부채총계 자본총계 매출액 영업이익 순이익
# 2024.12.31 11,774 9,740 2,033 6,399 -7,795 -7,665
# 2023.12.31 11,920 2,462 9,457 3,973 -7,202
# --------------------------------------------------
#
# === 청크 2 ===
# 유형: 주변지역 동종업체 (응용 소프트웨어 개발 및 공급업)
# 길이: 1029 문자
# 내용 미리보기:
# 03. 소속산업 분석
# www.nicebizline.com
# 네오사피엔스(주)│ 883-86-00767
# 산업개요 산업설명
# J58222 : 응용 소프트웨어 개발 및 공급업
# 산업명 응용 소프트웨어 개발 및 공급업
# 컴퓨터에서 특정한 업무 처리를 위하여 기능 및 프로세스를 프로그램화 하여 자동적으
# 산업코드 J58222
# 로 처리하는 범용성의 응용 소프트웨어를 개발하는
# --------------------------------------------------
#
# === 청크 3 ===
# 유형: 주요 수익성비율
# 길이: 859 문자
# 내용 미리보기:
# 04. 수익성 분석
# www.nicebizline.com
# 네오사피엔스(주)│ 883-86-00767
# 주요 수익성비율
# 수익성비율 단위 2024.12.31 2023.12.31 2022.12.31 한은평균 (2023) NICE산업평균 (2024)
# 매출액영업이익률 % -121.80 -181.24 -232.30 0.78 -
# 총자본순이익률 % -64.70 -46.71
# --------------------------------------------------

# %% [markdown]
# ### Embedding

# %%
vectorstore_docs

# %%
# !pip install torch
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langchain_community.vectorstores import FAISS
import torch

# %%
from dotenv import load_dotenv
import os
# [2] 환경 변수 로드 및 설정
load_dotenv()
hf_token = os.getenv('HUGGINGFACE_TOKEN')  # .env 파일에서 HUGGINGFACE_TOKEN 불러오기

if not hf_token:
    raise ValueError("Hugging Face 토큰이 설정되지 않았습니다. .env 파일을 확인해주세요.")

# GPU 사용 가능 여부 확인
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# !pip install sentence-transformers
# [3] 임베딩 모델 초기화
model_name = "jhgan/ko-sbert-nli"
model_kwargs = {'device': device}
encode_kwargs = {'normalize_embeddings': True}  # 코사인 유사도를 위한 정규화

embeddings = HuggingFaceBgeEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

# %%
# [4] FAISS 벡터 저장소 생성
vectorstore = FAISS.from_documents(
    documents=vectorstore_docs,
    embedding=embeddings
)

# %%
# 벡터 저장소에 실제로 저장된 문서 확인
print("\n=== 저장된 문서 수 ===")
print(f"총 문서 수: {len(vectorstore.docstore._dict)}")

# 샘플 문서의 메타데이터 구조 확인
print("\n=== 샘플 문서 메타데이터 ===")
sample_doc_id = list(vectorstore.docstore._dict.keys())[0]
print(vectorstore.docstore._dict[sample_doc_id].metadata)
# Out:
# === 저장된 문서 수 ===
# 총 문서 수: 354
#
# === 샘플 문서 메타데이터 ===
# {'document_type': 'financial_report', 'table_type': 'unknown', 'source': 'data\\기업분석_보고서_국문_네오사피엔스_202504301027.pdf', 'file_path': 'data\\기업분석_보고서_국문_네오사피엔스_202504301027.pdf', 'page': 0, 'total_pages': 16, 'Creator': 'OZ Report Viewer', 'CreationDate': 'D:20250430102758', 'Producer': 'oz', 'Author': 'Forcs Co.,Ltd.', 'Title': 'NCO1100M00OZ01.ozr', 'Subject': '', 'Keywords': '', 'company_name': '네오사피엔스', 'report_date': '202504301027', 'source_file': '기업분석_보고서_국문_네오사피엔스_202504301027.pdf'}

# %% [markdown]
# ### 임베딩 테스트

# %%
# [1] 재무 관련 검색을 위한 적절한 table_type 매핑
FINANCIAL_TABLE_TYPES = {
    "매출액": "주요 재무상황 (단위 : 백만원)",
    "수익성": "주요 수익성비율",
    "안정성": "주요 안정성비율",
    "성장성": "주요 성장성 및 활동성비율",
    "차입금": "차입금구조(GAAP) (단위: 백만원, %)"
}

# [2] 수정된 검색 코드
print("=== 재무 데이터 검색 테스트 ===")
queries = [
    {
        "query": "최근 3년간의 매출액 추이는?",
        "table_type": "주요 재무상황 (단위 : 백만원)"
    },
    {
        "query": "영업이익률이 가장 낮은 연도는?",
        "table_type": "주요 수익성비율"
    },
    {
        "query": "인건비가 매출액에서 차지하는 비중은?",
        "table_type": "주요 재무상황 (단위 : 백만원)"
    }
]

for query_info in queries:
    print(f"\n[검색 쿼리] {query_info['query']}")
    try:
        results = vectorstore.similarity_search(
            query=query_info['query'],
            k=1,
            filter={"table_type": query_info['table_type']}
        )
        if results:
            print(f"검색 결과: {results[0].page_content[:200]}")
        else:
            print("검색 결과가 없습니다.")
    except Exception as e:
        print(f"검색 중 오류 발생: {e}")
    print("-" * 50)
# Out:
# === 재무 데이터 검색 테스트 ===
#
# [검색 쿼리] 최근 3년간의 매출액 추이는?
# 검색 결과가 없습니다.
# --------------------------------------------------
#
# [검색 쿼리] 영업이익률이 가장 낮은 연도는?
# 검색 결과: 04. 수익성 분석
# www.nicebizline.com
# (주)뤼이드│ 106-87-06394
# 주요 수익성비율
# 수익성비율 단위 2024.12.31 2023.12.31 2022.12.31 한은평균 (2023) NICE산업평균 (2024)
# 매출액영업이익률 % -191.35 -350.53 -834.17 0.78 -
# 총자본순이익률 % -11.29 -24.40 -35
# --------------------------------------------------
#
# [검색 쿼리] 인건비가 매출액에서 차지하는 비중은?
# 검색 결과가 없습니다.
# --------------------------------------------------

# %% [markdown]
# ### 벡터DB 저장 및 로드

# %%
# [6] 벡터 저장소 저장
save_path = "data/vectordb/financial_bge_ko"
vectorstore.save_local(save_path)

# %%
# 저장된 벡터 DB 로드
loaded_vectorstore = FAISS.load_local(
    folder_path=save_path,
    embeddings=embeddings,
    allow_dangerous_deserialization=True  # 안전한 소스에서 로드할 때만 True로 설정
)
print("벡터 DB 로드 완료!")

# [3] 로드된 벡터 DB 테스트
def test_loaded_vectorstore():
    # 간단한 쿼리 테스트
    query = "뤼튼테크놀로지스 재무상태표?"
    results = loaded_vectorstore.similarity_search(
        query=query,
        k=3,
        # filter={"table_type": "주요 재무상황 (단위 : 백만원)"}
    )
    
    print("=== 로드된 벡터 DB 테스트 ===")
    print(f"검색 쿼리: {query}")
    if results:
        print(f"검색 결과: {results[0].page_content[:200]}")
    else:
        print("검색 결과가 없습니다.")

# 테스트 실행
test_loaded_vectorstore()
# Out:
# 벡터 DB 로드 완료!
# === 로드된 벡터 DB 테스트 ===
# 검색 쿼리: 뤼튼테크놀로지스 재무상태표?
# 검색 결과: 04. 수익성 분석
# www.nicebizline.com
# (주)뤼튼테크놀로지스│ 202-81-67042
# 주요 수익성비율
# 수익성비율 단위 2024.12.31 2023.12.31 2022.12.31 한은평균 (2023) NICE산업평균 (2024)
# 매출액영업이익률 % -960.38 -5086.18 -585.96 0.78 -
# 총자본순이익률 % -253.87 -19

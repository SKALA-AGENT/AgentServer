# %% [markdown]
# # Tech Agent 테스트
#
# 각 도구들의 기능을 테스트합니다.

# %%
from dotenv import load_dotenv
from tools.tech_agent_tools.patent_search import patent_search_tool
from tools.tech_agent_tools.tech_news_analyzer import tech_news_tool

# 환경 변수 로드
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 1. GitHub 분석 테스트

# %%
github = github_analysis_tool()
company = "뤼튼테크놀로지스"  # 당근마켓 GitHub 조직명

# 조직 정보 조회
org_info = github.get_organization_info(company)
print("\n=== 조직 정보 ===")
print(org_info)

# 주요 레포지토리 조회
repos = github.get_repositories(company)
print("\n=== 주요 레포지토리 ===")
for repo in repos:
    print(f"\n{repo['name']}:")
    print(f"- Stars: {repo['stars']}")
    print(f"- Forks: {repo['forks']}")
    print(f"- Language: {repo['language']}")
    print(f"- Description: {repo['description']}")

# 기여 통계
stats = github.get_contribution_stats(company)
print("\n=== 기여 통계 ===")
print(f"최근 90일 커밋 수: {stats['recent_commits']}")
print(f"활성 기여자 수: {stats['active_contributors']}")
# Out:
# === 조직 정보 ===
# {}
#
# === 주요 레포지토리 ===
#
# === 기여 통계 ===
# 최근 90일 커밋 수: 0
# 활성 기여자 수: 0

# %% [markdown]
# ## 2. 특허 검색 테스트

# %%
# 특허 분석기 인스턴스 생성
patent = patent_search_tool()

# 분석 대상 기업
company = "뤼튼테크놀로지스"

# 특허 분석 실행
result = patent.analyze_patents(company)

# 최근 특허 출력
print("\n=== 최근 특허 ===")
for p in result["patents"]:
    print(f"\n제목: {p['title']}")
    print(
        f"번호: {', '.join(p['patent_numbers']) if p['patent_numbers'] else '정보 없음'}"
    )
    print(f"날짜: {p['published_date']}")
    print(f"요약: {p['summary']}")

# 통계 정보 출력
print("\n=== 특허 통계 ===")
print(f"총 특허 수: {result['patent_count']}")

print("\n연도별 특허 수:")
for year, count in result["year_trend"]:
    print(f"{year}: {count}건")

print("\n상위 기술 분야:")
for field, count in result["top_tech_fields"]:
    print(f"{field}: {count}건")

print("\n기술 키워드 목록:")
print(", ".join(result["tech_keywords"]))
# Out:
# === 최근 특허 ===
#
# 제목: 과기정통부, ICT 유니콘 육성사업에 뤼튼 등 15개사 선정
# 번호: 정보 없음
# 날짜:
# 요약: 2020년 처음 지원을 시작해 3년간 총 44개 유망 기업을 지원했고, 이를 통해 투자 유치 2611억원, 매출액 4058억원, 고용창출 1131명, 특허 출원(등록)...
#
# 제목: "좋은 스타트업 요소 다 갖췄다"…생성AI 강자 '뤼튼'에 투자한 ...
# 번호: 정보 없음
# 날짜:
# 요약: 서울대 전기정보공학부를 졸업하고 스타트업 전문 변리사로서 지난 10년간 인공지능을 비롯한 IT 신기술 분야의 특허 업무를 수행했다. 현재는 동국대...
#
# 제목: [AX 혁신의 주역]뤼튼, 생활형 AI 서비스로 MAU 1000만 돌파 ...
# 번호: 정보 없음
# 날짜:
# 요약: 특히 에이전티카는 AI 에이전트 개발에 있어 가장 큰 장애물로 꼽히던 문제들을 해결했다. 고급 거대언어모델(LLM)조차 외부 시스템과 연동 시 부정확한 도구 선택이나 매개변수 오류로 인해 실패율이 높았던 기존 문제점을 극복, 인간 개입 없이도 안정적이고 효과적인 AI 에이전트 구현을 가능하게 한다.
#
# 뤼튼은 창업 초기부터 오픈소스 개발에 대한 확신을 바탕으로 프로젝트를 진행해왔다. 회사의 비전은 AI가 전기, 인터넷, 공기처럼 모두가 누릴 수 있는 보편재가 되는 것이다. 에이전티카 공개를 통해 단순 AI 에이전트를 쉽게 사용할 수 있게 하는 수준을 넘어, 누구나 블로그를 만들 듯 자체 AI 에이전트 시스템을 자유롭게 개발할 수 있는 생태계를 조성하고자 한다.
#
# 에이전티카 공개로 뤼튼은 전국민 AI 보급과 산업 현장 혁신이라는 두 축의 비전을 더욱 구체화하며, AI 대중화 및 산업 혁신을 선도하는 국내 대표 AI 기업으로서 입지를 확고히 할 전망이다. [...] [AX 혁신의 주역]뤼튼, 생활형 AI 서비스로 MAU 1000만 돌파한다
#
#
#
# 작게
#
# 보통
#
# 크게
#
# 인공지능(AI) 선도 기업 뤼튼테크놀로지스는 생활형 AI 서비스로 월간활성이용자(MAU) 1000만명 돌파를 청사진으로 제시했다. 전 국민 AI 보급과 산업 혁신을 주도하겠다는 각오다.
#
# 뤼튼은 창립 4주년을 맞아 지난 4월 14일, 오픈소스 AI 에이전트 프레임워크 '에이전티카(Agentica)'를 전 세계 개발자들에게 무료 공개했다. 에이전티카는 '깃허브(Github)'를 통해 배포되며, 누구나 쉽게 AI 에이전트를 개발하고 운영할 수 있는 오픈소스다.
#
# 뤼튼은 지난해부터 생활형 AI 서비스를 중심으로 본격적 성장에 나서며 MAU를 500만에서 1000만으로 두 배 이상 확대하는 것을 목표로 하고 있다. 이를 통해 국내 AI 서비스 시장에서 명실상부한 1위 사업자로 자리매김한다는 계획이다. [...] 뤼튼이 추구하는 로드맵은 크게 두 축으로 나뉜다. 첫 번째는 '전 국민 대상 AI 보급'으로, 1인 1 AI 시대를 열기 위한 생활형 AI 서비스 제공이다. 두 번째 축은 기업 및 산업 현장에 혁신을 이끌 AI 에이전트를 보급하는 것이다. 에이전티카는 이 두 번째 축의 핵심 프로젝트다. 디지털 경제에서 기업의 업무와 운영 방식을 근본적으로 바꾸는 역할을 할 것으로 기대된다.
#
# 최근 AI 모델과 서비스가 보편재화되는 상황에서, 기업의 AX는 더 이상 선택이 아닌 필수가 되고 있다. AI를 활용해 비용을 절감하고 생산성을 극대화하는 시대에 AX를 도입하지 않는 기업은 경쟁에서 도태될 수밖에 없다. 뤼튼은 이러한 AX 트렌드를 선도하며 기업들이 혁신을 가속화할 수 있도록 앞장서고자 한다....
#
# 제목: 중동 이어 미국까지 사로잡은 '뤼튼'…1000억원대 투자 유치
# 번호: 정보 없음
# 날짜:
# 요약: 특히 중동 지역 진출을 위해 지난해 아랍에미리트(UAE) 두바이에 사무소를 열었던 인공지능(AI) 서비스 플랫폼 기업 '뤼튼테크놀로지스'가 1000억원대...
#
# 제목: 뤼튼테크놀로지스, LLM 자동 추천·적용부터 전면 무료화까지
# 번호: 정보 없음
# 날짜:
# 요약: 뤼튼테크놀로지스, LLM 자동 추천·적용부터 전면 무료화까지···'AI 메가 플랫폼' 도약 선언
#
# 페이스북
#
# X(트위터)
#
# 메일
#
# URL 복사
#
# 작게
#
# 보통
#
# 크게
#
# “뤼튼테크놀로지스는 생성 인공지능(AI) 시대의 새로운 막을 열기 위해 'AI 메가 플랫폼'으로 도약할 것입니다.”
#
# 이세영 뤼튼테크놀로지스 대표는 19일 한국 프레스센터에서 미디어 데이를 열고 이 같은 내용을 담은 2024년 사업 계획을 발표했다.
#
# 뤼튼테크놀로지스는 국내 대표 AI 포털 서비스 기업이다. 지난 4월 플랫폼을 출시한 지 불과 9개월 만에 매주 10.04%씩 35배 고성장해 가입자수 200만명을 앞뒀다.
#
# 이 대표는 'AI 메가 플랫폼' 도약 전략으로 △쇄신(Renovation) △혁신(Innovation) △확장(Expansion) 세가지를 제시했다. [...] 이 대표는 “뤼튼 서비스의 강점은 GPT를 포함한 고성능, 최신 생성 AI 모델을 무제한 무료로 선택하면서 즐길 수 있다는 것”이라면서 “내년도부터는 유저가 선택을 고민할 필요없이 뤼튼이 직접 최적 LLM을 조합해서 제공할 것”이라고 말했다.
#
# 이 대표는 “앞으로는 많은 앱이 하나의 AI 메가 플랫폼에 흡수되고 종속될 것”이라면서 “뤼튼은 내년부터 이미 법인 설립을 마친 일본을 포함해서 중동, 기타 이아시아 지역에서 초고속 성장을 이어갈 것”이라고 강조했다.
#
# 류태웅 기자 bigheroryu@etnews.com
#
# 과기정통부, 고려대 등 4개 대학서 AI 신진 연구자 양성
#
# SW 많이 본 기사
#
# 주요 행사 ❯
#
# HOT 영상 ❯
#
# 사업자명 : 전자신문인터넷
# 사업자번호 : 107-81-80959
# 발행·편집인: 심규호
# 청소년보호책임자: 김태권
#
# Copyright © Electronic Times Internet. All Rights Reserved. [...] 먼저 쇄신을 위해 기존 기업로고(CI)와 슬로건 등을 전면 변경한다. 이에 맞춰 공식 홈페이지를 새로 런칭하고, 뤼튼 포털 변경·적용도 새해 1분기까지 마무리한다.
#
# 혁신 첫 단추는 '플랫폼 전면 무료화'다. 이미 무료인 플랫폼 서비스를 향후에도 유료로 전환하지 않겠다고 못 박았다.
#
# 그는 “이용자가 빠른 속도로 차등 없이 '뤼튼 포털'을 무료로, 무제한으로 사용할 수 있도록 도와왔다”면서 “향후에도 무료 정책을 혼동하지 않도록 다시 한 번 (모든 서비스) 무료화를 공식화한다”고 말했다.
#
# 이 대표는 'AI 메가 플랫폼'으로 도약에 핵심인 '최적 대규모언어모델(LLM) 조합 및 제공' 기능을 공개했다.
#
# 그동안 모든 유저는 뤼튼 플랫폼에서 GPT-4 , PaLM2, 하이퍼클로바, Claude-2 등 대표 LLM 가운데 하나를 선택해 사용할 수 있었다.
#
# 새롭게 공개된 기능은 뤼튼 AI가 이들 LLM 가운데 유저별 상황과 선호에 맞춰 최적 LLM을 선택, 제시한다....
#
# 제목: 뤼튼, 1080억원 투자 유치 마무리…유니콘 입성 초읽기
# 번호: 정보 없음
# 날짜:
# 요약: 인공지능(AI) 서비스 플랫폼 기업 뤼튼테크놀로지스가 830억원의 추가 투자를 유치하며 최종 1080억원 규모로 시리즈B 라운드를 마무리했다고 31일...
#
# 제목: 산업 > 2025.04.02
# 번호: 정보 없음
# 날짜:
# 요약: 10년 끌어온 유전자가위 특허분쟁, 올 상반기 '윤곽' [바이오마켓 인사이드] ... 뤼튼테크놀로지스, 1080억 투자 유치 [투자ABC] · 여권 스캔하면 정보 자동...
#
# 제목: '미래 오픈AI' 다 모았다…한경 MOOK 발간
# 번호: 정보 없음
# 날짜:
# 요약: ... 뤼튼테크놀로지스, AI 챗봇 '이루다'를 개발한 스캐터랩 등 유명 스타트업의 미래 수익 모델과 창업자의 포부 등을 한눈에 볼 수 있다. 가격은 2만...
#
# === 특허 통계 ===
# 총 특허 수: 8
#
# 연도별 특허 수:
# 2020: 1건
# 2024: 1건
#
# 상위 기술 분야:
# 인공지능: 5건
# 바이오: 1건
#
# 기술 키워드 목록:
# 인공지능, 바이오

# %% [markdown]
# ## 3. 기술 뉴스 분석 테스트

# %%
"""AI 스타트업의 기술력 및 혁신성 분석 사용 예시"""

# 분석 실행
analyzer = tech_news_tool()
company = "필라이즈"

try:
    # 기술력 및 혁신성 분석 실행
    tech_innovation_data = analyzer.analyze_technology_innovation(company)

    # 핵심 기술 키워드 출력
    print(f"\n=== {company}의 핵심 기술 키워드 ===")
    if tech_innovation_data["key_technologies"]:
        for tech, count in tech_innovation_data["key_technologies"]:
            print(f"{tech}: {count}회 언급")
    else:
        print("핵심 기술 키워드를 찾을 수 없습니다.")

    # 기술 혁신 관련 뉴스 출력
    print(f"\n=== {company}의 기술 혁신 관련 뉴스 ===")
    if tech_innovation_data["tech_innovations"]:
        for article in tech_innovation_data["tech_innovations"]:
            print(f"제목: {article['title']}")
            if article.get("published_date"):
                print(f"날짜: {article['published_date']}")
            print(f"URL: {article['url']}")
            print(f"내용: {article['content']}")
            print(f"요약: {article['summary']}")
            print("-" * 50)
    else:
        print("기술 혁신 관련 뉴스를 찾을 수 없습니다.")


except Exception as e:
    print(f"오류 발생: {e}")
    import traceback

    traceback.print_exc()
# Out:
# === 필라이즈의 핵심 기술 키워드 ===
# AI: 5회 언급
# 특허: 3회 언급
# 인공지능: 2회 언급
# 알고리즘: 1회 언급
#
# === 필라이즈의 기술 혁신 관련 뉴스 ===
# 제목: 개인 맞춤형 건강 관리 앱, 필라이즈
# URL: https://brunch.co.kr/@boldydesign/159
# 내용: 필라이즈는 자체 특허를 보유한 AI를 활용해 개인의 건강 데이터를 분석하고, 이를 바탕으로 맞춤형 영양제와 식단을 추천해주는 서비스에요. 대부분
# 요약: 필라이즈는 자체 특허를 보유한 AI를 활용해 개인의 건강 데이터를 분석하고, 이를 바탕으로 맞춤형 영양제와 식단을 추천해주는 서비스에요. 대부분...
# --------------------------------------------------
# 제목: AI가 맞춤형 영양제 추천?...월 72만명 쓰는 '필라이즈' 비결은 ...
# URL: https://www.mk.co.kr/news/business/10756895
# 내용: 영양제 챙겨 먹는 사람이라면 한 번쯤 이런 의문이 들 것이다. 몸에 좋다 하니 챙겨 먹기는 한다. 직장인 10명 중 9명이 최소 1종 이상의 영양제를 챙겨 먹는다는 통계(인크루트 4월 설문)가 있을 정도다. 다만 대부분 영양제 전문가가 아니다 보니 과연 내 몸에 맞는 영양제를 먹고 있는지 현실적으로 알기 힘들다. 인크루트 설문에서도 자신이 먹는 영양제의 효능, 부작용 등 세부 정보를 아는 응답자는 전체의 15.3%에 그쳤다.
#
# 이런 문제를 해결하기 위해 뛰어든 스타트업이 필라이즈(Pillyze)다. 창업자는 신인식 대표, 윤정원 부대표다. 두 사람은 이미 스타트업 경영을 해본 경험이 있다. 호텔 예약 서비스로 유명한 ‘데일리호텔’에서 각각 대표와 최고전략책임자(CSO)로 일했다. [...] A. 필라이즈는 Pill(영양제) + Analyze(분석)의 뜻을 가진 합성어로, 영양제를 개인에 맞게 AI로 분석, 관리해주는 ‘영양제 맞춤 분석 서비스’라는 의미를 담고 있다.
#
# Q. 영양제 추천은 어떤 방식으로 이뤄지나.
#
# A. 먼저 개인 건강 데이터(10년 치 건강검진 기록, 키, 체중, 건강 고민, 알러지, 흡연 여부 등)를 유저로부터 받는다. 이를 국내외 2만6000여개 제품, 1200개 영양 성분를 AI(인공지능)로 종합 분석한 뒤 각 유저에게 맞는 영양제를 추천해주는 식이다. 개인에 따라 다른 영양 성분의 최적 섭취량, 추천, 비추천 성분 등을 종합하고 AI 알고리즘을 사용해 영양제 추천에 반영하고 있다. 이 밖에 알맞은 섭취량과 성분에 따른 부작용 등도 검사해주고 있다.
#
# Q. 요새 AI가 핫한데, 필라이즈도 AI를 쓴다고. [...] 그렇다. 필라이즈의 자체 개발 AI 엔진 ‘파나케이아’는 초개인화 검색, 영양제, 식단 분석·추천 등에 활용되고 있다. 파나케이아만의 차별화된 추천 알고리즘과 기술력을 바탕으로 3개월 만에 5건의 특허도 획득했다.
#
# Q. 맞춤형 영양제는 어떤 장점이 있나.
#
# A. 개인의 건강 상태, 복용 약물 등에 따라 추천, 주의 성분, 최적 섭취량이 다르기 때문에 유명하고 좋다고 알려진 제품이라고 해도 나에게는 효과가 기대했던 것보다 적거나 나아가 부작용 위험이 있을 수 있다.
#
# 예를 들어 루테인은 눈 건강에 좋은 영양 성분으로 잘 알려져 있지만 흡연자가 루테인을 장기간 고용량 복용 시 폐암 위험을 높일 수 있어 주의해야 한다. 또, 피로 회복을 위한 홍삼은 당뇨약을 복용하는 사람에게는 저혈당 증상을 일으킬 수 있다. 때문에 건강기능식품을 섭취하기 전 전문가와 상담하는 것은 필수다.
# 요약: 영양제 챙겨 먹는 사람이라면 한 번쯤 이런 의문이 들 것이다. 몸에 좋다 하니 챙겨 먹기는 한다. 직장인 10명 중 9명이 최소 1종 이상의 영양제를 챙겨 먹는다는 통계(인크루트 4월 설문)가 있을 정도다. 다만 대부분 영양제 전문가가 아니다 보니 과연 내 몸에 맞는 영양제를 먹고 있는지 현실적으로 알기 힘들다. 인크루트 설문에서도 자신이 먹는 영양제의 효능, 부작용 등 세부 정보를 아는 응답자는 전체의 15.3%에 그쳤다.
#
# 이런 문제를 해결하기 위해 뛰어든 스타트업이 필라이즈(Pillyze)다. 창업자는 신인식 대표, 윤정원 부...
# --------------------------------------------------
# 제목: 필라이즈, 영양제 AI 조합 분석 150만 건 돌파
# URL: https://www.edaily.co.kr/News/Read?newsId=02007366639050952&mediaCodeNo=257
# 내용: 필라이즈 앱은 인공지능(AI)를 통해 현재 섭취 중인 영양제를 입력하면 점수를 통해 섭취 상태를 분석할 수 있고 부족하거나 과하게 섭취 중인 영양제
# 요약: 필라이즈 앱은 인공지능(AI)를 통해 현재 섭취 중인 영양제를 입력하면 점수를 통해 섭취 상태를 분석할 수 있고 부족하거나 과하게 섭취 중인 영양제...
# --------------------------------------------------
# 제목: 필라이즈, 유저별 음식 혈당 반응 비교 기능 출시
# URL: https://www.mk.co.kr/news/it/10969262
# 내용: 초개인화 특허 AI '파나케이아'를 통해 누적된 건강 데이터를 세밀하게 분석하고, 연속혈당측정기(CGM)와 데이터를 결합하여 당뇨, 비만, 노화 방지를
# 요약: 초개인화 특허 AI '파나케이아'를 통해 누적된 건강 데이터를 세밀하게 분석하고, 연속혈당측정기(CGM)와 데이터를 결합하여 당뇨, 비만, 노화 방지를...
# --------------------------------------------------
# 제목: AI 영양관리 플랫폼 필라이즈...120억 규모 시리즈A 투자 유치
# URL: https://www.mk.co.kr/news/stock/10812537
# 내용: 아울러 초개인화 AI 기술을 바탕으로 ▲체성분 분석·유전자 검사 등을 고도화하고 ▲ 필라이즈 헬스케어 전문가 팀을 확대할 예정이다. 필라이즈는 지난
# 요약: 아울러 초개인화 AI 기술을 바탕으로 ▲체성분 분석·유전자 검사 등을 고도화하고 ▲ 필라이즈 헬스케어 전문가 팀을 확대할 예정이다. 필라이즈는 지난...
# --------------------------------------------------

# %% [markdown]
# ## 4. 전체 기술 분석 테스트

# %%
from dotenv import load_dotenv
from patent_search import patent_search_tool
from tech_news_analyzer import tech_news_tool
from agents.tech_agent import format_analysis_to_markdown


# 환경 변수 로드
load_dotenv()

from agents.tech_agent import create_tech_analysis_agent

agent = create_tech_analysis_agent("앨리스그룹")
result = agent.invoke({})
print(result)
# markdown = format_analysis_to_markdown("뤼튼테크놀리지", result)
# print(markdown)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 from patent_search import patent_search_tool
#       3 from tech_news_analyzer import tech_news_tool
# ----> 4 from agents.tech_agent import format_analysis_to_markdown
#       7 # 환경 변수 로드
#       8 load_dotenv()
#
# ModuleNotFoundError: No module named 'agents'
